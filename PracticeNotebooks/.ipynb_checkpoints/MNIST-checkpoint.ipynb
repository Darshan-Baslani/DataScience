# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-07-18 09:31:39.578780: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-18 09:31:39.581333: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-18 09:31:39.618212: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-18 09:31:41.733785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Checking version of Tensorflow ans Keras
print(f"Tensorflow Version {tf.__version__}")
print(f"Keras Version {tf.keras.__version__}")
# Out:
# Tensorflow Version 2.16.1
# Keras Version 3.3.3

# %%
tf.config.list_physical_devices("GPU")
# Out:
# []

# %%
mnist = tf.keras.datasets.mnist

# %%
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

# %%
X_train_full.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
X_train_full[0][1].shape
# Out:
# (28,)

# %%
28*28
# Out:
# 784

# %%
# Dividing training data into validation and train
#  Scale the data between 0 to 1 by dividing it by 255. as its an unsigned data between 0-255 range
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

X_test = X_test / 255.

X_valid.shape, X_train.shape
# Out:
# ((5000, 28, 28), (55000, 28, 28))

# %%
plt.imshow(X_valid[0], cmap='binary')
plt.show()

# %%
plt.figure(figsize=(18,18))
sns.heatmap(X_train[0], annot=True, cmap='binary')
plt.show()

# %%
model_clf = tf.keras.models.Sequential(
    [
        tf.keras.layers.Flatten(input_shape=[28,28]),
        tf.keras.layers.Dense(300, activation="relu"),
        tf.keras.layers.Dense(100, activation="relu"),
        tf.keras.layers.Dense(10, activation="softmax")
    ]
)

# %%
model_clf.layers
# Out:
# [<Flatten name=flatten, built=True>,
#  <Dense name=dense, built=True>,
#  <Dense name=dense_1, built=True>,
#  <Dense name=dense_2, built=True>]

# %%
model_clf.compile(optimizer="SGD", metrics=["accuracy"], loss=tf.losses.sparse_categorical_crossentropy)

# %%
steps = model_clf.fit(X_train, y_train, batch_size=256, validation_data=(X_valid, y_valid), epochs=3)
# Out:
# Epoch 1/3
# 2024-07-18 09:31:56.523083: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 172480000 exceeds 10% of free system memory.
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3571 - loss: 2.0261 - val_accuracy: 0.7996 - val_loss: 1.0608
# Epoch 2/3
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8147 - loss: 0.9109 - val_accuracy: 0.8648 - val_loss: 0.6017
# Epoch 3/3
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8643 - loss: 0.5673 - val_accuracy: 0.8860 - val_loss: 0.4624

# %%
pd.DataFrame(steps.history).plot()
# Out:
# <Axes: >

# %%
y_test[:3]
# Out:
# array([7, 2, 1], dtype=uint8)

# %%
model_clf.evaluate(X_test, y_test)
# Out:
# 205/313 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.8569 - loss: 0.5400
# 2024-07-18 09:32:05.629970: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 31360000 exceeds 10% of free system memory.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8631 - loss: 0.5188
# [0.4594554305076599, 0.8827999830245972]

# %%
y_pred = model_clf.predict(X_test[:3])
np.argmax(y_pred, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# array([7, 2, 1])

# %% [markdown]
# # PyToch Implementation

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root = "data",
    train = True,
    download = True,
    transform = ToTensor(),
)

test_data = datasets.MNIST(
    root = "data",
    train = False,
    download = True,
    transform = ToTensor(),
)
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|███████████████████████████████████████████| 9912422/9912422 [01:41<00:00, 97760.21it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████████████████████████████████████████| 28881/28881 [00:00<00:00, 104536.54it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|██████████████████████████████████████████| 1648877/1648877 [00:15<00:00, 107788.94it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100%|███████████████████████████████████████████████| 4542/4542 [00:00<00:00, 1002606.64it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
batch_size = 256
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([256, 1, 28, 28])
# Shape of y: torch.Size([256]) torch.int64

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layers = nn.Sequential(
            nn.Linear(28*28, 300),
            nn.ReLU(),
            nn.Linear(300, 100),
            nn.ReLU(),
            nn.Linear(100, 10)
        )

    def forward(self, X):
        X = self.flatten(X)
        logits = self.layers(X)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=300, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=300, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )

# %%
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset) # just used to print data
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # X, y = X.to(device), y.to(device)

        # computing predictions
        pred = model(X)
        loss = loss_fn(pred, y)

        # backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}] len:{len(X)}")


def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            test_loss /= num_batches
            correct /= size
            # print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f}")

# %%
def train_demo(dataloader, model, loss_fn, optimizer):
    for batch, (X, y) in enumerate(dataloader):
            X_to, y = X.to(device), y.to(device)
            # print(X==X_to)


train_demo(train_dataloader, model, loss, optimizer)

# %%
epochs = 2
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss, optimizer)
    test(test_dataloader, model, loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.847441  [  256/60000] len:256
# loss: 1.549461  [25856/60000] len:256
# loss: 1.265454  [51456/60000] len:256
# Epoch 2
# -------------------------------
# loss: 1.169295  [  256/60000] len:256
# loss: 0.943703  [25856/60000] len:256
# loss: 0.840954  [51456/60000] len:256
# Done!
